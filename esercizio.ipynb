# %%
#legge tutto in un colpo: Dironly
def dirOnly(istanza):
    metodi = dir(istanza)
    risultato = []
    for m in metodi:
        if not m.startwith('_'):
            risultato.append(m)
    return(risultato)

# %% [markdown]
# Valore sentinella= valore che deve coincidere
# registra in questo programma il prezzo di un articolo e se si tratta di un animale o no, come faccio a farlo finire sto programma? Per questo si mette il valore sentinella.

# %%
f = open('lista_con_sconto.txt')

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
with open('lista_con_sconto.txt', 'r') as file:
    lines = file.readlines()
    print(lines)
# Out:
# ['2.79 N\n', '2.79 N\n', '2.79 N\n', '200.00 Y\n', '2.79 N']

# %%
prices = []
isPet = []
sconto = 0.0
with open('lista_con_sconto.txt', 'r') as file:
    righe = file.readlines()
    for riga in righe:
        campi = riga.split()
        prices.append(float(campi[0]))
        if campi[1].upper() == 'Y':
            isPet.append(True)
        else:
            isPet.append(False)
nItems = len(prices)
if (nItems) == len(isPet):
    sconto = discount(prices, isPet, nItems)
print(sconto)
# Out:
# [2.79, 2.79, 2.79, 200.0, 2.79]
# [False, False, False, True, False]
# 5
# None

# %%
pro_insieme = [False, False, False, True, False]
index = 0
for value in pro_insieme:
    print(index, value)
    index = index + 1
# Out:
# 0 False
# 1 False
# 2 False
# 3 True
# 4 False

# %%
def discount(prezzi, animale, numero):
    risultato = 0.0
    base_sconto = 0.0
    numero_animali = 0
    if len(set(animale)) == 2: #verifico la presenza di articoli e animali
        index = 0
        for value in animale:
            if value:
                numero_animali = numero_animali + 1
            else:
                base_sconto = base_sconto + prezzi[index]
            index = index + 1
        if (numero - numero_animali) >= 5: #verifico la soglia 5 articoli
            risultato = base_sconto * 0.2
    return risultato
# Out:
#   Cell In[37], line 11
#     base_sconto = base_ sconto + prezzi[index]
#                         ^
# SyntaxError: invalid syntax

# %%
s = '2.79 N\n'
s.split()
# Out:
# ['2.79', 'N']

# %%
len(prices)
# Out:
# 5
